# %%
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen

site= "https://www.goibibo.com/hotels-international/hotels-in-dubai-ct/"
hdr = {'User-Agent': 'Mozilla/5.0'}
req = Request(site,headers=hdr)
page = urlopen(req)
data = BeautifulSoup(page, 'html.parser')
print(data)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <script>
#           var starttime = new Date();
#         </script>
# <title data-react-helmet="true">Hotels in Dubai, 1020 Dubai Hotels from ₹1612 + upto 30% off</title>
# ...

# %%
# find all the sections with specifiedd class name
cards_data = data.find_all('div', attrs={'class', 'HotelCardstyles__WrapperSectionMetaDiv-sc-1s80tyk-5 jjHNnh'})

# print(cards_data)
# total number of cards
print('Total Number of Cards Found : ', len(cards_data))

# source code of hotel cards
#for card in cards_data:
#    print(card)

for card in cards_data:
    hotel_name = card.find('div', attrs={'class', 'HotelCardstyles__HotelNameWrapperDiv-sc-1s80tyk-16 jhHHUQ'})
    hotel_price = card.find('div', attrs={'class', 'HotelCardstyles__CurrentPriceTextWrapper-sc-1s80tyk-31 jOUtYR'})
    print(hotel_name.a.span.text,hotel_price.p.text)

# %%
import pandas as pd

# create a list to store the data
scraped_data = []

for card in cards_data:

    # initialize the dictionary
    card_details = {}

    # get the hotel name
    hotel_name = card.find('div', attrs={'class', 'HotelCardstyles__HotelNameWrapperDiv-sc-1s80tyk-16 jhHHUQ'})
    hotel_name = hotel_name.a.span.text

    # get the room price
    room_price = card.find('div', attrs={'class', 'HotelCardstyles__CurrentPriceTextWrapper-sc-1s80tyk-31 jOUtYR'})
    room_price = room_price.p.text

    # add data to the dictionary
    card_details['hotel_name'] = hotel_name
    card_details['room_price'] = room_price

    # append the scraped data to the list
    scraped_data.append(card_details)

# create a data frame from the list of dictionaries
dataFrame = pd.DataFrame.from_dict(scraped_data)

print(dataFrame)

# save the scraped data as CSV file
dataFrame.to_csv('file.csv', index=False)
# Out:
#                                            hotel_name room_price
# 0   Emirates Grand Hotel Apartments -Near Burj Kha...       5037
# 1      Millennium Central Downtown- Near Burj Khalifa       8346
# 2                                 ROVE Downtown Dubai      12220
# 3                                      Fairmont Dubai      15920
# 4                Gevora Hotel - World's Tallest Hotel       7896
# 5   Mercure Gold Hotel Al Mina Road - Near Dubai F...       6677
# 6                               Palazzo Versace Dubai      22900
# 7             Golden Sands Hotel Apartments Bur Dubai       8551
# 8                     Grand Excelsior Hotel Bur Dubai       6281
# 9               Holiday International Hotel Bur Dubai       9276
# 10               Best Western Plus Pearl Creek- Deira       6162
# 11             Moon Valley Hotel Apartments Bur Dubai       8242
# 12                                 Grand Square Hotel       4137
# ...
